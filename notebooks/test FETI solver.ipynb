# %%
import sys
sys.path.insert(0,'..')

from pyfeti.cases.case1 import K1, K2, B1_dict, B2_dict, global_to_local_dict_1, global_to_local_dict_2, dofs_dict

# %%
K1
# Out:
# matrix([[ 1.03846154e+10,  3.75000000e+09, -6.34615385e+09,
#          -2.88461538e+08, -5.19230769e+09, -3.75000000e+09,
#           1.15384615e+09,  2.88461538e+08,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.75000000e+09,  1.03846154e+10,  2.88461538e+08,
#           1.15384615e+09, -3.75000000e+09, -5.19230769e+09,
#          -2.88461538e+08, -6.34615385e+09,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-6.34615385e+09,  2.88461538e+08,  2.07692308e+10,
#          -2.20232010e-02,  2.30769231e+09, -2.10478306e-02,
#          -5.19230769e+09,  3.75000000e+09,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %%
B1_dict
# Out:
# {(1, 2): <6x18 sparse matrix of type '<class 'numpy.int32'>'
#  	with 6 stored elements in COOrdinate format>}
